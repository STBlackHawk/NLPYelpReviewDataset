# %%
# %matplotlib inline
import matplotlib
import seaborn as sns
sns.set()
matplotlib.rcParams['figure.dpi'] = 144

# %% [markdown]
# # NLP: Analyzing Review Text

# %% [markdown]
# Unstructured data makes up the vast majority of data.  We will use NLP basics to handle Yelp review data. Our objective is to be able to extract the sentiment (positive or negative) from review text.

# %% [markdown]
# ## Download and parse the data

# %% [markdown]
# The data set can be downloaded from Yelp:
# 'yelp_train_academic_dataset_review_reduced.json.gz'

# %% [markdown]
# The training data are a series of JSON objects, in a Gzipped file. Python supports Gzipped files natively: [`gzip.open`](https://docs.python.org/2/library/gzip.html) has the same interface as `open`, but handles `.gz` files automatically.
#
# The built-in json package has a `loads()` function that converts a JSON string into a Python dictionary.  We could call that once for each row of the file. [`ujson`](http://docs.micropython.org/en/latest/library/ujson.html) has the same interface as the built-in `json` library, but is *substantially* faster (at the cost of non-robust handling of malformed json).  We will use that inside a list comprehension to get a list of dictionaries:

# %%
from sklearn import base
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer, HashingVectorizer, TfidfTransformer
from sklearn.linear_model import Ridge
import dill
from sklearn.decomposition import TruncatedSVD
import pandas as pd

# %%
import gzip
import ujson as json

with gzip.open('yelp_train_academic_dataset_review_reduced.json.gz') as f:
    data = [json.loads(line) for line in f]

# %% [markdown]
# Scikit Learn will want the labels in a separate data structure, so let's pull those out now.

# %%
stars = [row['stars'] for row in data]

# %%
#Reading review ids in a pandas data frame
review_data = pd.read_json("yelp_train_academic_dataset_review_reduced.json.gz", lines=True,compression="gzip")

# %%
review_data.head()
# Out:
#               business_id       date               review_id  stars  \
# 0  vcNAWiLM4dR7D2nwwJ7nCA 2013-04-19  _ePLBPrkrf4bhyiKWEn4Qg      1
# 1  JwUE5GmEO-sH1FuwJgKBlQ 2009-05-04  ow1c4Lcl3ObWxDC2yurwjQ      4
# 2  JwUE5GmEO-sH1FuwJgKBlQ 2011-03-31  4iPPOQIo5Mr1NAUPUgCUrQ      4
# 3  JwUE5GmEO-sH1FuwJgKBlQ 2012-01-08  _utPYHIdXeq8CqQ4iYD1bw      3
# 4  JwUE5GmEO-sH1FuwJgKBlQ 2012-08-26  gksnzyc9jQ9hNXESjvTrQw      3
#
#                                                 text    type  \
# 0  I don't know what Dr. Goldberg was like before...  review
# 1  If you like lot lizards, you'll love the Pine ...  review
# 2  Only went here once about a year and a half ag...  review
# 3  Ate a Saturday morning breakfast at the Pine C...  review
# 4  This is definitely not your usual truck stop. ...  review
#
#                   user_id                                 votes
# 0  Qrs3EICADUKNFoUq2iHStA  {'funny': 0, 'useful': 0, 'cool': 0}
# 1  ZYaumz29bl9qHpu-KVtMGA  {'funny': 6, 'useful': 0, 'cool': 0}
# 2  EEYwj6_t1OT5WQGypqEPNg  {'funny': 0, 'useful': 0, 'cool': 0}
# 3  MnXcXwr0keJpkIiwuPsOKg  {'funny': 0, 'useful': 1, 'cool': 0}
# 4  wC8r-m6KHifL6R2i8ok8yg  {'funny': 0, 'useful': 1, 'cool': 0}

# %% [markdown]
# ### Notes:

# %% [markdown]
# 1. [Pandas](http://pandas.pydata.org/) is able to read JSON text directly.  Use the `read_json()` function with the `lines=True` keyword argument.
#
# 2. There are obvious mistakes in the data.  There is no need to correct them.

# %% [markdown]
# ## Building models

# %% [markdown]
# we will build and train different estimator that predicts the star rating given certain features. In most cases we will use a pipeline containing custom or pre-built transformers and an existing estimator.
#
#
# Also in some models we find it useful to serialize the trained models to disk.  This will allow to reload it after restarting the Jupyter notebook, without needing to retrain it.  We will be using the [`dill` library](https://pypi.python.org/pypi/dill) for this (although the [`joblib` library](http://scikit-learn.org/stable/modules/model_persistence.html) also works). We will Use
# ```python
# dill.dump(estimator, open('estimator.dill', 'w'))
# estimator = dill.load(open('estimator.dill', 'r'))

# %% [markdown]
# ## bag_of_words_model

# %% [markdown]
# We will build a linear model predicting the star rating based on the count of the words in each document (bag-of-words model). We will use a [`CountVectorizer`](http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html#sklearn.feature_extraction.text.CountVectorizer) or [`HashingVectorizer`](http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.HashingVectorizer.html#sklearn.feature_extraction.text.HashingVectorizer) to produce a feature matrix giving the counts of each word in each review. Then we will feed this in to linear model to predict the number of stars from each review.

# %%
class ColumnSelectTransformer(base.BaseEstimator, base.TransformerMixin):
    
    def __init__(self, col_names):
        self.col_names = col_names  # We will need these in transform()
        self.data = {}
    def fit(self, X, y=None):
        # This transformer doesn't need to learn anything about the data,
        # so it can just return self without any further processing
        return self
    
    def transform(self, X):
        # Return an array with the same number of rows as X and one
        # column for each in self.col_names
        return [row[self.col_names] for row in X]

# %%
bag_of_words_est = Pipeline([
    ("Cst", ColumnSelectTransformer("text")),
    ("HashingVect", HashingVectorizer()),
    # Frequency filter (if necessary)
    ("RG", Ridge())
])
bag_of_words_est.fit(data, stars)
# Out:
# Pipeline(memory=None,
#      steps=[('Cst', ColumnSelectTransformer(col_names='text')), ('HashingVect', HashingVectorizer(alternate_sign=True, analyzer='word', binary=False,
#          decode_error='strict', dtype=<class 'numpy.float64'>,
#          encoding='utf-8', input='content', lowercase=True,
#          n_features=1048576, ngr...it_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001))])

# %% [markdown]
# ## normalized_model

# %% [markdown]
# Normalization is key for good linear regression. Previously, we used the count as the normalization scheme.  Add in a normalization transformer to your pipeline to improve the score.
#
# [TF-IDF](https://en.wikipedia.org/wiki/Tf%E2%80%93idf) is a common normalization scheme used in text processing.

# %%
bag_of_words_normalized_est = Pipeline([
    ("Cst", ColumnSelectTransformer("text")),
    ("HashingVect", HashingVectorizer()),
    ("Tfid_normalizer", TfidfTransformer(use_idf=False)),
    ("RG", Ridge())
])
bag_of_words_normalized_est.fit(data, stars)

# %%
dill.dump(bag_of_words_normalized_est, open('bag_of_words_normalized_est.dill', 'wb'))

# %% [markdown]
# ## bigram_model

# %% [markdown]
# In a bigram model, we'll consider both single words and pairs of consecutive words that appear.  This is going to be a much higher dimensional problem (large $p$) so you should be careful about overfitting.

# %%
bag_of_words_bigram_est = Pipeline([
    ("Cst", ColumnSelectTransformer("text")),
    ("HashingVect", HashingVectorizer(ngram_range = (1,2))),
    ("Tfid_normalizer", TfidfTransformer(use_idf=False)),
    ("RG", Ridge())
])
bag_of_words_bigram_est.fit(data, stars)

# %%
dill.dump(bag_of_words_bigram_est, open('bag_of_words_bigram_est.dill', 'wb'))

# %%
bag_of_words_bigram_est = dill.load(open('bag_of_words_bigram_est.dill', 'rb'))

# %% [markdown]
# ## food_bigrams

# %% [markdown]
# We want to find collocations --- that is, bigrams that are "special" and appear more often than we'd expect from chance. We can think of the corpus as defining an empirical distribution over all *n*-grams.  We can find word pairs that are unlikely to occur consecutively based on the underlying probability of their words. Mathematically, if $p(w)$ be the probability of a word $w$ and $p(w_1 w_2)$ is the probability of the bigram $w_1 w_2$, then we want to look at word pairs $w_1 w_2$ where the statistic
#
#   $$ \frac{p(w_1 w_2)}{p(w_1) p(w_2)} $$
#
# is high.  We will find the top 100 (mostly food) bigrams with this statistic with the 'right' prior factor (see below). We will estimate the probabilities by counting and using `CountVectorizer` to count up how many times each word and each bigram appears in each review.

# %% [markdown]
# We can use business data set to map business with their id and category which can be downloaded from Yelp:
# "yelp_train_academic_dataset_business.json.gz"

# %%
business_data = pd.read_json("yelp_train_academic_dataset_business.json.gz", lines=True,compression="gzip")

# %% [markdown]
# Each row of this file corresponds to a single business.  The category key gives a list of categories for each; take all where "Restaurants" appears.

# %%
business_data.head()
# Out:
#                                           attributes             business_id  \
# 0                      {'By Appointment Only': True}  vcNAWiLM4dR7D2nwwJ7nCA
# 1  {'Take-out': True, 'Good For': {'dessert': Fal...  JwUE5GmEO-sH1FuwJgKBlQ
# 2  {'Take-out': True, 'Good For': {'dessert': Fal...  uGykseHzyS5xAMWoN6YUqA
# 3  {'Take-out': True, 'Wi-Fi': 'free', 'Takes Res...  LRKJF43s9-3jG9Lgx4zODg
# 4  {'Take-out': True, 'Has TV': False, 'Outdoor S...  RgDg-k9S5YD_BaxMckifkg
#
#                                           categories       city  \
# 0                        [Doctors, Health & Medical]    Phoenix
# 1                                      [Restaurants]  De Forest
# 2              [American (Traditional), Restaurants]  De Forest
# 3  [Food, Ice Cream & Frozen Yogurt, Fast Food, R...  De Forest
# 4                             [Chinese, Restaurants]  De Forest
#
#                                         full_address  \
# 0  4840 E Indian School Rd\nSte 101\nPhoenix, AZ ...
# 1            6162 US Highway 51\nDe Forest, WI 53532
# 2                505 W North St\nDe Forest, WI 53532
# 3              4910 County Rd V\nDe Forest, WI 53532
# 4                 631 S Main St\nDe Forest, WI 53532
#
#                                                hours   latitude   longitude  \
# 0  {'Tuesday': {'close': '17:00', 'open': '08:00'...  33.499313 -111.983758
# 1                                                 {}  43.238893  -89.335844
# 2  {'Monday': {'close': '22:00', 'open': '06:00'}...  43.252267  -89.353437
# 3  {'Monday': {'close': '22:00', 'open': '10:30'}...  43.251045  -89.374983
# 4  {'Monday': {'close': '22:00', 'open': '11:00'}...  43.240875  -89.343722
#
#                           name neighborhoods  open  review_count  stars state  \
# 0            Eric Goldberg, MD            []  True             7    3.5    AZ
# 1         Pine Cone Restaurant            []  True            26    4.0    WI
# 2   Deforest Family Restaurant            []  True            16    4.0    WI
# 3                     Culver's            []  True             7    4.5    WI
# 4  Chang Jiang Chinese Kitchen            []  True             3    4.0    WI
#
#        type
# 0  business
# 1  business
# 2  business
# 3  business
# 4  business

# %%
restaurant_ids = business_data["business_id"].loc[business_data["categories"].apply(lambda x:"Restaurants" in x)]
# Out:
# 1        JwUE5GmEO-sH1FuwJgKBlQ
# 2        uGykseHzyS5xAMWoN6YUqA
# 3        LRKJF43s9-3jG9Lgx4zODg
# 4        RgDg-k9S5YD_BaxMckifkg
# 9        _wZTYYL7cutanzAnJUTGMA
# 12       zOc8lbjViUZajbY7M0aUCQ
# 13       UgjVZTSOaYoEvws_lAP_Dw
# 15       SKLw05kEIlZcpTD5pqma8Q
# 16       77ESrCo7hQ96VpCWWdvoxg
# 21       KTqNU4plO23583DYAMGXYg
# 26       ShEYKerTwb2LSORE5o_s7A
# 27       HaBkx5PwvbBpQ2iNCgHnVQ
# 28       KW6HejC-67KSL9J8Cz1dSw
# 29       wl-7A4jC0f27MOEmW-XTbQ
# 31       suQyHycqv8nA7EualcUB3g
# 35       uga5g16PncJOtY7Sc3A05w
# 38       xbJ9tdGbcVJIUkNgHSCwZQ
# 39       koRLvzIl-4fCybOIdk56jA
# 44       cruBFtsFaBuhX_I72uU8pA
# 45       X47o6R2rWiqGqvBtC7VS3Q
# 48       lN-5-YTsaJr_IByyA476iw
# 50       IEmqrFe96NOhU07TA0rZdw
# 53       KFJ1jBfFkRfyn3AoAUl3YQ
# 56       G1qUGBNYNS220jKlPAlFsA
# 59       6oDZ78JiSKjXVLcurCpnhw
# 61       kiAsweI4sOjDzGyz3Y_HsQ
# 63       q8fD82us6uuGufvI44NoAg
# 64       oc0rCahXOaJeHLzzDdSfyA
# 65       Nj0vQjUYjaa7qbvZlEr2jQ
# 67       B0Vuwn6Hugc-0U5n31YBfg
#                   ...
# 37874    cOPKrTpfmse01coqXiX-CQ
# 37876    HXmKSaJa7hXsgeCozQs-uQ
# 37879    sih8j621A66QoiUFues5qQ
# 37880    6c-_klCWVUwnFlXSRUzaSA
# 37881    wd3nrdoEpikmGcf4NX0ziA
# 37883    WVEBPBymHcpYXPsXryPoNQ
# 37884    ScSwwoFcIC0mf1vU-6p8eQ
# 37885    q1QRFM3Rh8K9jPMWNus6hA
# 37889    nuHftEWNyMIsa4R4OpqlQg
# 37896    M3G_xbxxfkupkemCZzXh9g
# 37898    cb4YeNdl6MUWis906tzFVQ
# 37901    vZ4CIMfeos6K7OyYDIlwrQ
# 37902    WgsKcV4zZ2JnxUj9lKdn9Q
# 37904    LsKF7GFQ0j5U1jLMwq0_hQ
# 37906    Ah5sMocfo1FTk6vekMLM6g
# 37909    aybLDQRhUwOr7WoQfdofPQ
# 37911    fmfiSDAJtjxbnRBBtYhnNw
# 37913    xT1MO7MLMp3jK4XT1LXiKA
# 37914    51vtDjP79vBjaI5dbkPoPw
# 37915    F8ZrWvngdHYnKrALwZAdBw
# 37917    0EXVIF07vw-QTTy9V7-ebg
# 37923    8K4pWvuJmGWXDgCugYKYvw
# 37924    wmm19sGdCiL5IZhViYQY2Q
# 37926    5se9c1ggSm2oMrnWO3ZSgw
# 37928    EYpqqsJZ3L2EFAPK-NEOFA
# 37929    KN-3Sg8TZ-y67026TFwmjw
# 37930    ZpB2O-WAbbRHdP0V8GrwXA
# 37931    OEUIE8VBa1BbBfr5EPcTOA
# 37932    yZXEELxi8KMwzXCHP345GQ
# 37936    BMjggIgOghBMEXPo8q7q3w
# Name: business_id, Length: 12876, dtype: object

# %%
#Check points
assert len(restaurant_ids) == 12876

# %%
#two data frames are review_data and business_data

# %%
review_data[["business_id","text"]].head()
# Out:
#               business_id                                               text
# 0  vcNAWiLM4dR7D2nwwJ7nCA  I don't know what Dr. Goldberg was like before...
# 1  JwUE5GmEO-sH1FuwJgKBlQ  If you like lot lizards, you'll love the Pine ...
# 2  JwUE5GmEO-sH1FuwJgKBlQ  Only went here once about a year and a half ag...
# 3  JwUE5GmEO-sH1FuwJgKBlQ  Ate a Saturday morning breakfast at the Pine C...
# 4  JwUE5GmEO-sH1FuwJgKBlQ  This is definitely not your usual truck stop. ...

# %%
#Creating a new data frame
restaurant_reviews = pd.merge(review_data[["business_id","text"]],restaurant_ids.to_frame(), on="business_id")

# %%
bigrams = CountVectorizer(min_df=21,stop_words="english",ngram_range = (2,2))
bigramsVec = bigrams.fit_transform(restaurant_reviews_txt.values)
unigram = CountVectorizer(stop_words="english")
unigramVec = unigram.fit_transform(restaurant_reviews_txt.values)
unigramVec = unigramVec.sum(axis=0)
bigramsVec = bigramsVec.sum(axis=0)

# %%
dill.dump(unigramVec, open('unigramVec.dill', 'wb'))

# %%
dill.dump(bigramsVec, open('bigramsVec.dill', 'wb'))

# %%
bgram = bigramsVec.A1
ngram = unigramVec.A1

# %%
def FindProb(bigram, bigramCount ,unigram, unigramCount):
    bigramNames = bigram.get_feature_names()
    unigramDict = unigram.vocabulary_
    Normalized = []
    for i in range(len(bigramNames)):
        w = bigramNames[i].split(" ")
        num = bigramCount[i]
        d1 = unigramCount[unigramDict[w[0]]]+30
        d2 = unigramCount[unigramDict[w[1]]]+30
        Normalized.append(num/(d1*d2))
    return Normalized

# %%
Norm = FindProb(bigrams, bgram, unigram, ngram)

# %%
names=bigrams.get_feature_names()
names
# Out:
# ['00 00',
#  '00 dinner',
#  '00 lunch',
#  '00 meal',
#  '00 people',
#  '00 person',
#  '00 plus',
#  '00 pm',
#  '00 tip',
#  '00 worth',
#  '10 00',
#  '10 10',
#  '10 11',
#  '10 12',
#  '10 13',
#  '10 14',
#  '10 15',
#  '10 20',
#  '10 30',
#  '10 30am',
#  '10 30pm',
#  '10 45',
#  '10 50',
#  '10 95',
#  '10 99',
#  '10 bucks',
#  '10 burger',
#  '10 coupon',
#  '10 days',
#  '10 different',
#  '10 discount',
#  '10 dishes',
#  '10 dollars',
#  '10 drink',
#  '10 feet',
#  '10 food',
#  '10 free',
#  '10 good',
#  '10 got',
#  '10 great',
#  '10 just',
#  '10 lunch',
#  '10 meal',
#  '10 miles',
#  '10 min',
#  '10 mins',
#  '10 minute',
#  '10 minutes',
#  '10 order',
#  '10 ordered',
#  '10 oz',
#  '10 people',
#  '10 person',
#  '10 pizza',
#  '10 plate',
#  '10 plus',
#  '10 pm',
#  '10 really',
#  '10 sandwich',
#  '10 seconds',
#  '10 service',
#  '10 small',
#  '10 stars',
#  '10 tables',
#  '10 time',
#  '10 times',
#  '10 tip',
#  '10 year',
#  '10 years',
#  '100 00',
#  '100 bucks',
#  '100 challenge',
#  '100 degree',
#  '100 degrees',
#  '100 different',
#  '100 people',
#  '100 person',
#  '100 sure',
#  '100 times',
#  '100 worth',
#  '1000 island',
#  '10x better',
#  '11 00',
#  '11 10',
#  '11 12',
#  '11 15',
#  '11 30',
#  '11 30am',
#  '11 45',
#  '11 50',
#  '11 95',
#  '11 99',
#  '11 bucks',
#  '11 people',
#  '11 pm',
#  '11 years',
#  '12 00',
#  '12 14',
#  '12 15',
#  '12 20',
#  '12 30',
#  '12 30pm',
#  '12 45',
#  '12 50',
#  '12 95',
#  '12 99',
#  '12 bucks',
#  '12 dollars',
#  '12 hours',
#  '12 inch',
#  '12 minutes',
#  '12 oz',
#  '12 people',
#  '12 year',
#  '12 years',
#  '13 00',
#  '13 50',
#  '13 95',
#  '13 99',
#  '13 bucks',
#  '13 years',
#  '14 00',
#  '14 95',
#  '14 99',
#  '14 bucks',
#  '14 oz',
#  '15 00',
#  '15 20',
#  '15 25',
#  '15 30',
#  '15 95',
#  '15 99',
#  '15 bucks',
#  '15 different',
#  '15 dollars',
#  '15 min',
#  '15 mins',
#  '15 minute',
#  '15 minutes',
#  '15 people',
#  '15 person',
#  '15 pm',
#  '15 tables',
#  '15 times',
#  '15 tip',
#  '15 years',
#  '16 00',
#  '16 50',
#  '16 95',
#  '16 99',
#  '16 bucks',
#  '16 course',
#  '16 oz',
#  '16 people',
#  '16 years',
#  '16th street',
#  '17 00',
#  '17 95',
#  '17 99',
#  '18 00',
#  '18 95',
#  '18 99',
#  '18 bucks',
#  '18 gratuity',
#  '18 tip',
#  '18 years',
#  '19 95',
#  '19 99',
#  '19th ave',
#  '1st time',
#  '1st visit',
#  '20 00',
#  '20 25',
#  '20 30',
#  '20 40',
#  '20 bucks',
#  '20 different',
#  '20 dollars',
#  '20 eat',
#  '20 food',
#  '20 gratuity',
#  '20 just',
#  '20 lunch',
#  '20 min',
#  '20 mins',
#  '20 minute',
#  '20 minutes',
#  '20 oz',
#  '20 people',
#  '20 person',
#  '20 times',
#  '20 tip',
#  '20 worth',
#  '20 years',
#  '21 95',
#  '21 99',
#  '21st birthday',
#  '22 95',
#  '22 oz',
#  '23 95',
#  '24 95',
#  '24 99',
#  '24 hour',
#  '24 hours',
#  '24 hr',
#  '24 hrs',
#  '24 oz',
#  '25 00',
#  '25 30',
#  '25 95',
#  '25 bucks',
#  '25 cent',
#  '25 cents',
#  '25 dinner',
#  '25 dollars',
#  '25 gift',
#  '25 min',
#  '25 mins',
#  '25 minute',
#  '25 minutes',
#  '25 people',
#  '25 person',
#  '25 years',
#  '26 95',
#  '29 99',
#  '2nd 3rd',
#  '2nd best',
#  '2nd course',
#  '2nd floor',
#  '2nd time',
#  '2nd visit',
#  '30 00',
#  '30 30',
#  '30 40',
#  '30 45',
#  '30 bucks',
#  '30 dinner',
#  '30 dollars',
#  '30 food',
#  '30 friday',
#  '30 got',
#  '30 lunch',
#  '30 min',
#  '30 mins',
#  '30 minute',
#  '30 minutes',
#  '30 people',
#  '30 person',
#  '30 place',
#  '30 pm',
#  '30 reservation',
#  '30 saturday',
#  '30 seated',
#  '30 seconds',
#  '30 sunday',
#  '30 tip',
#  '30 wait',
#  '30 years',
#  '30pm friday',
#  '30pm saturday',
#  '30th birthday',
#  '32 oz',
#  '35 00',
#  '35 40',
#  '35 min',
#  '35 minutes',
#  '35 person',
#  '365 challenge',
#  '39 99',
#  '3pm 6pm',
#  '3rd floor',
#  '3rd time',
#  '3rd visit',
#  '40 00',
#  '40 50',
#  '40 bucks',
#  '40 dinner',
#  '40 dollars',
#  '40 min',
#  '40 mins',
#  '40 minute',
#  '40 minutes',
#  '40 people',
#  '40 person',
#  '40 tip',
#  '40 worth',
#  '40 years',
#  '45 min',
#  '45 mins',
#  '45 minute',
#  '45 minutes',
#  '45 person',
#  '45 pm',
#  '4th july',
#  '4th star',
#  '4th time',
#  '50 00',
#  '50 50',
#  '50 60',
#  '50 bucks',
#  '50 cent',
#  '50 cents',
#  '50 diner',
#  '50 dinner',
#  '50 dollars',
#  '50 extra',
#  '50 food',
#  '50 gift',
#  '50 good',
#  '50 great',
#  '50 just',
#  '50 lunch',
#  '50 meal',
#  '50 minutes',
#  '50 ordered',
#  '50 people',
#  '50 person',
#  '50 really',
#  '50 slice',
#  '50 small',
#  '50 steak',
#  '50 tip',
#  '50 worth',
#  '50 years',
#  '50th birthday',
#  '5th star',
#  '5th wine',
#  '60 00',
#  '60 minutes',
#  '60 person',
#  '75 cents',
#  '75 stars',
#  '7pm saturday',
#  '7th ave',
#  '7th st',
#  '7th street',
#  '8oz filet',
#  '90 minute',
#  '90 minutes',
#  '90 time',
#  '95 95',
#  '95 dinner',
#  '95 eat',
#  '95 good',
#  '95 great',
#  '95 lunch',
#  '95 person',
#  '99 99',
#  '99 breakfast',
#  '99 buffet',
#  '99 cent',
#  '99 cents',
#  '99 dinner',
#  '99 eat',
#  '99 good',
#  '99 got',
#  '99 great',
#  '99 lunch',
#  '99 person',
#  '99 price',
#  '99 steak',
#  '99 time',
#  'able accommodate',
#  'able bring',
#  'able eat',
#  'able enjoy',
#  'able finish',
#  'able good',
#  'able handle',
#  'able hear',
#  'able make',
#  'able order',
#  'able pick',
#  'able place',
#  'able sample',
#  'able seat',
#  'able seated',
#  'able share',
#  'able sit',
#  'able table',
#  'able talk',
#  'able taste',
#  'able tell',
#  'able try',
#  'able use',
#  'able walk',
#  'able watch',
#  'absolute best',
#  'absolute favorite',
#  'absolute perfection',
#  'absolute worst',
#  'absolutely adore',
#  'absolutely amazing',
#  'absolutely awesome',
#  'absolutely awful',
#  'absolutely beautiful',
#  'absolutely best',
#  'absolutely delicious',
#  'absolutely delightful',
#  'absolutely delish',
#  'absolutely die',
#  'absolutely disgusting',
#  'absolutely divine',
#  'absolutely excellent',
#  'absolutely fabulous',
#  'absolutely fantastic',
#  'absolutely favorite',
#  'absolutely flavor',
#  'absolutely gorgeous',
#  'absolutely great',
#  'absolutely hate',
#  'absolutely horrible',
#  'absolutely incredible',
#  'absolutely love',
#  'absolutely loved',
#  'absolutely notch',
#  'absolutely outstanding',
#  'absolutely perfect',
#  'absolutely phenomenal',
#  'absolutely recommend',
#  'absolutely return',
#  'absolutely ridiculous',
#  'absolutely terrible',
#  'absolutely try',
#  'absolutely wonderful',
#  'absolutely worst',
#  'absolutely worth',
#  'accept cash',
#  'accept credit',
#  'accommodate large',
#  'accommodating food',
#  'accommodating friendly',
#  'accommodating large',
#  'according menu',
#  'acquired taste',
#  'act like',
#  'acted like',
#  'acting like',
#  'acts like',
#  'actual food',
#  'actual meal',
#  'actual meat',
#  'actual menu',
#  'actual restaurant',
#  'actually able',
#  'actually ask',
#  'actually asked',
#  'actually ate',
#  'actually bad',
#  'actually best',
#  'actually better',
#  'actually brought',
#  'actually came',
#  'actually care',
#  'actually come',
#  'actually cooked',
#  'actually decent',
#  'actually delicious',
#  'actually did',
#  'actually didn',
#  'actually don',
#  'actually eat',
#  'actually eaten',
#  'actually eating',
#  'actually ended',
#  'actually enjoy',
#  'actually enjoyed',
#  'actually felt',
#  'actually food',
#  'actually fresh',
#  'actually gave',
#  'actually getting',
#  'actually going',
#  'actually good',
#  'actually got',
#  'actually great',
#  'actually just',
#  'actually kind',
#  'actually know',
#  'actually like',
#  'actually liked',
#  'actually little',
#  'actually look',
#  'actually looked',
#  'actually looking',
#  'actually looks',
#  'actually lot',
#  'actually love',
#  'actually make',
#  'actually nice',
#  'actually order',
#  'actually ordered',
#  'actually place',
#  'actually prefer',
#  'actually pretty',
#  'actually quite',
#  'actually really',
#  'actually said',
#  'actually sat',
#  'actually saw',
#  'actually serve',
#  'actually served',
#  'actually spicy',
#  'actually surprised',
#  'actually taste',
#  'actually tasted',
#  'actually tastes',
#  'actually tasty',
#  'actually think',
#  'actually thought',
#  'actually took',
#  'actually tried',
#  'actually try',
#  'actually turned',
#  'actually use',
#  'actually walked',
#  'actually want',
#  'actually wanted',
#  'actually wasn',
#  'actually went',
#  'actually worth',
#  'adam richman',
#  'add additional',
#  'add bacon',
#  'add bit',
#  'add cheese',
#  'add chicken',
#  'add egg',
#  'add extra',
#  'add flavor',
#  'add great',
#  'add ins',
#  'add insult',
#  'add list',
#  'add little',
#  'add meat',
#  'add nice',
#  'add ons',
#  'add order',
#  'add salt',
#  'add sauce',
#  'add star',
#  'add toppings',
#  'added bacon',
#  'added bonus',
#  'added chicken',
#  'added extra',
#  'added flavor',
#  'added great',
#  'added just',
#  'added list',
#  'added little',
#  'added lot',
#  'added menu',
#  'added new',
#  'added nice',
#  'added touch',
#  'addition area',
#  'addition downtown',
#  'addition food',
#  'addition great',
#  'addition neighborhood',
#  'additional 10',
#  'additional charge',
#  'additional cost',
#  'adds charm',
#  'adds nice',
#  'admit food',
#  'admit little',
#  'admit place',
#  'admit pretty',
#  'admit ve',
#  'adobo fried',
#  'adorable little',
#  'adore place',
#  'adult beverage',
#  'adult beverages',
#  'adults child',
#  'adults kids',
#  'advantage happy',
#  'adventurous try',
#  'advice don',
#  'aesthetically pleasing',
#  'afford eat',
#  'affordable delicious',
#  'affordable food',
#  'affordable price',
#  'affordable prices',
#  'afraid ask',
#  'afraid try',
#  'afternoon evening',
#  'afternoon lunch',
#  'afternoon ordered',
#  'afternoon place',
#  'afternoon snack',
#  'afternoon tea',
#  'afternoon wasn',
#  'aged balsamic',
#  'aged beef',
#  'aged bone',
#  'aged cheddar',
#  'aged rib',
#  'aged steak',
#  'agedashi tofu',
#  'ago came',
#  'ago decided',
#  'ago did',
#  'ago didn',
#  'ago finally',
#  'ago food',
#  'ago friend',
#  'ago friends',
#  'ago good',
#  'ago got',
#  'ago great',
#  'ago just',
#  'ago love',
#  'ago loved',
#  'ago ordered',
#  'ago place',
#  'ago really',
#  'ago remember',
#  'ago service',
#  'ago think',
#  'ago thought',
#  'ago time',
#  'ago tried',
#  'ago ve',
#  'ago went',
#  'agree food',
#  'agree previous',
#  'agree reviewer',
#  'agree reviewers',
#  'agree reviews',
#  'agree yelpers',
#  'agreed best',
#  'agreed food',
#  'agua fresca',
#  'aguas frescas',
#  'ah mazing',
#  'ah yes',
#  'ahead make',
#  'ahead order',
#  'ahead ordered',
#  'ahead pick',
#  'ahead time',
#  'ahi poke',
#  'ahi salad',
#  'ahi tacos',
#  'ahi tuna',
#  'ain bad',
#  'ain cheap',
#  'aioli sauce',
#  'air conditioned',
#  'air conditioning',
#  'airport food',
#  'airport restaurant',
#  'ajo al',
#  'al carte',
#  'al dente',
#  'al forno',
#  'al fresco',
#  'al pastor',
#  'ala carte',
#  'alaskan crab',
#  'alaskan king',
#  'albacore tuna',
#  'albeit bit',
#  'albeit little',
#  'alcohol content',
#  'alcohol food',
#  'alcoholic beverage',
#  'alcoholic beverages',
#  'alcoholic drink',
#  'alcoholic drinks',
#  'ale house',
#  'alfredo chicken',
#  'alfredo pasta',
#  'alfredo sauce',
#  'alice cooper',
#  'alice wonderland',
#  'alla vodka',
#  'allowed order',
#  'alma school',
#  'almond butter',
#  'almond croissant',
#  'almond milk',
#  'aloha kitchen',
#  'alot better',
#  'alot food',
#  'alot people',
#  'alright food',
#  'alright special',
#  'alright ve',
#  'alternative fast',
#  'amazing absolutely',
#  'amazing actually',
#  'amazing amazing',
#  'amazing ambiance',
#  'amazing atmosphere',
#  'amazing authentic',
#  'amazing bad',
#  'amazing beef',
#  'amazing beer',
#  'amazing best',
#  'amazing better',
#  'amazing big',
#  'amazing bit',
#  'amazing boyfriend',
#  'amazing bread',
#  'amazing breakfast',
#  'amazing buffet',
#  'amazing burger',
#  'amazing burgers',
#  'amazing came',
#  'amazing cheese',
#  'amazing chef',
#  'amazing chicken',
#  'amazing chocolate',
#  'amazing cocktails',
#  'amazing coffee',
#  'amazing combination',
#  'amazing come',
#  'amazing cooked',
#  'amazing couldn',
#  'amazing course',
#  'amazing crust',
#  'amazing customer',
#  'amazing deal',
#  'amazing decor',
#  'amazing definitely',
#  'amazing delicious',
#  'amazing dessert',
#  'amazing desserts',
#  'amazing did',
#  'amazing didn',
#  'amazing different',
#  'amazing dining',
#  'amazing dinner',
#  'amazing dish',
#  'amazing dishes',
#  'amazing don',
#  'amazing drinks',
#  'amazing eat',
#  'amazing enjoyed',
#  'amazing especially',
#  'amazing experience',
#  'amazing favorite',
#  'amazing fish',
#  'amazing flavor',
#  'amazing flavors',
#  'amazing food',
#  'amazing french',
#  'amazing fresh',
#  'amazing fried',
#  'amazing friend',
#  'amazing friendly',
#  'amazing fries',
#  'amazing garlic',
#  'amazing good',
#  'amazing got',
#  'amazing great',
#  'amazing happy',
#  'amazing highly',
#  'amazing homemade',
#  'amazing hot',
#  'amazing huge',
#  'amazing husband',
#  'amazing italian',
#  'amazing job',
#  'amazing just',
#  'amazing light',
#  'amazing like',
#  'amazing little',
#  'amazing ll',
#  'amazing looking',
#  'amazing love',
#  'amazing loved',
#  'amazing lunch',
#  'amazing make',
#  'amazing maybe',
#  'amazing meal',
#  'amazing meat',
#  'amazing menu',
#  'amazing mexican',
#  'amazing new',
#  'amazing nice',
#  'amazing night',
#  'amazing oh',
#  'amazing order',
#  'amazing ordered',
#  'amazing overall',
#  'amazing owner',
#  'amazing people',
#  'amazing perfect',
#  'amazing perfectly',
#  'amazing pizza',
#  'amazing place',
#  'amazing pork',
#  'amazing portions',
#  'amazing pretty',
#  'amazing price',
#  'amazing prices',
#  'amazing probably',
#  'amazing quality',
#  'amazing really',
#  'amazing recommend',
#  'amazing red',
#  'amazing restaurant',
#  'amazing restaurants',
#  'amazing reviews',
#  'amazing salad',
#  'amazing salads',
#  'amazing salsa',
#  'amazing sandwich',
#  'amazing sandwiches',
#  'amazing sauce',
#  'amazing say',
#  'amazing seafood',
#  'amazing second',
#  'amazing selection',
#  'amazing seriously',
#  'amazing served',
#  'amazing server',
#  'amazing service',
#  'amazing shrimp',
#  'amazing spicy',
#  'amazing staff',
#  'amazing stars',
#  'amazing started',
#  'amazing steak',
#  'amazing super',
#  'amazing sure',
#  'amazing sushi',
#  'amazing sweet',
#  'amazing tacos',
#  'amazing taste',
#  'amazing tender',
#  'amazing thai',
#  'amazing thing',
#  'amazing things',
#  'amazing think',
#  'amazing thought',
#  'amazing time',
#  'amazing totally',
#  'amazing tried',
#  'amazing truly',
#  'amazing try',
#  'amazing usually',
#  'amazing value',
#  'amazing ve',
#  'amazing view',
#  'amazing views',
#  'amazing wait',
#  'amazing waiter',
#  'amazing waitress',
#  'amazing want',
#  'amazing wanted',
#  'amazing warm',
#  'amazing way',
#  'amazing went',
#  'amazing wife',
#  'amazing wine',
#  'amazing wish',
#  'amazing worth',
#  'amazingly delicious',
#  'amazingly fresh',
#  'amazingly good',
#  'ambiance amazing',
#  'ambiance awesome',
#  'ambiance beautiful',
#  'ambiance casual',
#  'ambiance cool',
#  'ambiance dark',
#  'ambiance decor',
#  'ambiance definitely',
#  'ambiance fantastic',
#  'ambiance food',
#  'ambiance friendly',
#  'ambiance fun',
#  'ambiance good',
#  'ambiance great',
#  'ambiance inside',
#  'ambiance just',
#  'ambiance like',
#  'ambiance little',
#  'ambiance love',
#  'ambiance nice',
#  'ambiance perfect',
#  'ambiance place',
#  'ambiance pretty',
#  'ambiance really',
#  'ambiance restaurant',
#  'ambiance service',
#  'ambiance stars',
#  'ambience food',
#  'ambience good',
#  'ambience great',
#  'ambience nice',
#  'ambience place',
#  'ambience service',
#  'america taco',
#  'american breakfast',
#  'american burger',
#  'american cheese',
#  'american chinese',
#  'american classic',
#  'american cuisine',
#  'american diner',
#  'american express',
#  'american fare',
#  'american fish',
#  'american food',
#  'american italian',
#  'american kobe',
#  'american mexican',
#  'american restaurant',
#  'american style',
#  'american wagyu',
#  'americanized chinese',
#  'americanized mexican',
#  'ami gabi',
#  'ample parking',
#  'ample portions',
#  'ample seating',
#  'amuse bouche',
#  'andouille sausage',
#  'andy sage',
#  'angel hair',
#  'angus beef',
#  'angus burger',
#  'animal style',
#  'anniversary dinner',
#  'annoying food',
#  'annoying thing',
#  'answer phone',
#  'answer question',
#  'answer questions',
#  'answer yes',
#  'answered phone',
#  'answered questions',
#  'answering phone',
#  'answering questions',
#  'anthony bourdain',
#  'anti pasta',
#  'antipasto salad',
#  'anxious try',
#  'anymore food',
#  'anymore just',
#  'anytime day',
#  'anytime soon',
#  'anyways food',
#  'anyways got',
#  'anyways ordered',
#  'anyways place',
#  'apache junction',
#  'apologized offered',
#  'apologized profusely',
#  'apologized said',
#  'apologized took',
#  'apologized wait',
#  'apparently don',
#  'apparently just',
#  'appetizer amazing',
#  'appetizer arrived',
#  'appetizer best',
#  'appetizer came',
#  'appetizer chicken',
#  'appetizer delicious',
#  'appetizer dessert',
#  'appetizer dish',
#  'appetizer drinks',
#  'appetizer entree',
#  'appetizer entrees',
#  'appetizer excellent',
#  'appetizer fried',
#  'appetizer good',
#  'appetizer got',
#  'appetizer great',
#  'appetizer just',
#  'appetizer like',
#  'appetizer main',
#  'appetizer meal',
#  'appetizer menu',
#  'appetizer order',
#  'appetizer ordered',
#  'appetizer plate',
#  'appetizer platter',
#  'appetizer pretty',
#  'appetizer really',
#  'appetizer salad',
#  'appetizer sampler',
#  'appetizer served',
#  'appetizer shrimp',
#  'appetizer soup',
#  'appetizer special',
#  'appetizer tasty',
#  'appetizer time',
#  'appetizers came',
#  'appetizers delicious',
#  ...]

# %%
Top = [[a, b] for a, b in zip(names, Norm)]
Top = sorted(Top, key=lambda x:-x[1])
Top
# Out:
# [['knick knacks', 0.007562008469449486],
#  ['rula bula', 0.0074211502782931356],
#  ['ropa vieja', 0.007165437302423604],
#  ['itty bitty', 0.006979062811565304],
#  ['dac biet', 0.006771780877299374],
#  ['gulab jamun', 0.006701414743112435],
#  ['patatas bravas', 0.006085192697768763],
#  ['puerto rican', 0.00590717299578059],
#  ['wal mart', 0.0057817998994469585],
#  ['bradley ogden', 0.005681818181818182],
#  ['lomo saltado', 0.005643738977072311],
#  ['vice versa', 0.005526083112290009],
#  ['valle luna', 0.00545578540577404],
#  ['kao tod', 0.005432595573440644],
#  ['artery clogging', 0.005151604356785399],
#  ['har gow', 0.005098257322951428],
#  ['pina colada', 0.00497787610619469],
#  ['bells whistles', 0.00496031746031746],
#  ['harry potter', 0.0048430840759395586],
#  ['aguas frescas', 0.004618473895582329],
#  ['ping pang', 0.004591710101762224],
#  ['casey moore', 0.0045281465472882575],
#  ['pin kaow', 0.004526935264825713],
#  ['cochinita pibil', 0.004387602688573563],
#  ['scantily clad', 0.004330343334364367],
#  ['demi glace', 0.004329004329004329],
#  ['lactose intolerant', 0.004305365956106269],
#  ['thit nuong', 0.004251700680272109],
#  ['kilt lifter', 0.004223206867903628],
#  ['moscow mule', 0.004161331626120359],
#  ['woody allen', 0.004147465437788019],
#  ['hustle bustle', 0.0040503557744937056],
#  ['dulce leche', 0.004048582995951417],
#  ['cabo wabo', 0.004023668639053254],
#  ['kee mao', 0.004022885750044699],
#  ['tres leches', 0.003855832453932949],
#  ['arnold palmer', 0.003838875371722087],
#  ['coca cola', 0.003791208791208791],
#  ['stainless steel', 0.0037313432835820895],
#  ['kool aid', 0.0037222436144269027],
#  ['osso bucco', 0.003703703703703704],
#  ['rick moonen', 0.003703703703703704],
#  ['van buren', 0.0036730945821854912],
#  ['huli huli', 0.0036506219578150353],
#  ['fleur lys', 0.0036409147798384346],
#  ['insult injury', 0.0035912725301531375],
#  ['quench thirst', 0.0035358405657344907],
#  ['bok choy', 0.0035146789532754445],
#  ['fogo chao', 0.003489084822481022],
#  ['jean philippe', 0.0034346846846846847],
#  ['toby keith', 0.003426791277258567],
#  ['tilted kilt', 0.0033677428801522804],
#  ['identity crisis', 0.003367003367003367],
#  ['parmigiano reggiano', 0.0033089515848136537],
#  ['hush puppies', 0.003302999662959218],
#  ['sierra bonita', 0.0032659726474790775],
#  ['nba finals', 0.003246753246753247],
#  ['panna cotta', 0.003243402624207578],
#  ['apache junction', 0.0032258064516129032],
#  ['petit fours', 0.0032141422257934912],
#  ['hong kong', 0.003181191583475982],
#  ['peter piper', 0.003129089150594527],
#  ['dean martin', 0.003060230908332174],
#  ['lechon kawali', 0.003042155584528466],
#  ['sauvignon blanc', 0.003040689960194604],
#  ['osso buco', 0.0030396558174335953],
#  ['kare kare', 0.00299072265625],
#  ['pet peeve', 0.002950071892508305],
#  ['croque madame', 0.002938517179023508],
#  ['adam richman', 0.0029088558500323207],
#  ['alice wonderland', 0.002895302138787709],
#  ['wi fi', 0.002843111915223572],
#  ['santa fe', 0.0028251081486713164],
#  ['pang pong', 0.002795682224120525],
#  ['monte carlo', 0.002767395054629097],
#  ['conveyor belt', 0.0027448322602507623],
#  ['lau lau', 0.0027431292376171004],
#  ['daniel boulud', 0.002709520695132206],
#  ['agua fresca', 0.0026936026936026937],
#  ['dietary restrictions', 0.0026798691860465116],
#  ['jean georges', 0.0026646364674533687],
#  ['caffe boa', 0.0026383910792512942],
#  ['pei wei', 0.002618783740302456],
#  ['huevos rancheros', 0.0026148320836746268],
#  ['ho hum', 0.0026090501426824296],
#  ['johnny rockets', 0.002609034267912773],
#  ['joel robuchon', 0.002567268308934486],
#  ['tar tar', 0.0025574084927273695],
#  ['beaten path', 0.0025487924427412888],
#  ['du jour', 0.0025420817588457574],
#  ['wolfgang puck', 0.00253099173553719],
#  ['bon appetit', 0.0025252525252525255],
#  ['flip flops', 0.0025194469813875856],
#  ['beverly hills', 0.0025173064820641915],
#  ['loco moco', 0.0025157023141129235],
#  ['cous cous', 0.002474093728710244],
#  ['baba ganoush', 0.002449520026481298],
#  ['smack dab', 0.0024452724732184445],
#  ['amuse bouche', 0.0024398395721925135],
#  ['bamboo shoots', 0.0024177949709864605],
#  ['dos equis', 0.0024176103830003816],
#  ['monte cristo', 0.002391772303276728],
#  ['mu shu', 0.0023853697323085077],
#  ['nam kao', 0.002380952380952381],
#  ['croque monsieur', 0.0023704546532024844],
#  ['tex mex', 0.0023617847982324706],
#  ['julian serrano', 0.0023182297154899895],
#  ['pet peeves', 0.0023112915045943967],
#  ['alice cooper', 0.002309087910275441],
#  ['neck woods', 0.002279102384291725],
#  ['mason jars', 0.002278344145814025],
#  ['dover sole', 0.0022713506965475467],
#  ['cheez whiz', 0.002268002268002268],
#  ['haus murphy', 0.0022474881015335803],
#  ['halo halo', 0.0022222222222222222],
#  ['du soleil', 0.002188868042526579],
#  ['pinot noir', 0.0021610017889087656],
#  ['carl jr', 0.0021474358974358974],
#  ['ami gabi', 0.0021432990601891405],
#  ['dolsot bibimbap', 0.002117362371445856],
#  ['poppy seed', 0.0021078431372549018],
#  ['surf turf', 0.002104717805912638],
#  ['hubert keller', 0.0020872865275142313],
#  ['pf changs', 0.0020511673006638324],
#  ['foo yung', 0.002050919377652051],
#  ['fort apache', 0.0020376175548589342],
#  ['mechanical bull', 0.00202020202020202],
#  ['dos molinos', 0.0020127474002012745],
#  ['carls jr', 0.002003205128205128],
#  ['bo hue', 0.0019989460102854857],
#  ['haji baba', 0.001994459833795014],
#  ['language barrier', 0.0019943019943019944],
#  ['steady stream', 0.0019905709795704557],
#  ['pun intended', 0.0019866740020783665],
#  ['baba ghanoush', 0.001983218916857361],
#  ['cha gio', 0.001973684210526316],
#  ['prix fixe', 0.001969345383488031],
#  ['kung pao', 0.0019670058190588815],
#  ['creature habit', 0.00195852534562212],
#  ['grey goose', 0.0019504876219054764],
#  ['woo hoo', 0.0019496632399858206],
#  ['sensory overload', 0.001946787800129786],
#  ['mario batali', 0.0019194271911663215],
#  ['james beard', 0.0019161982626469086],
#  ['shrugged shoulders', 0.0019146390107698445],
#  ['mamma mia', 0.0019130434782608696],
#  ['anthony bourdain', 0.0018901426198522251],
#  ['maryland parkway', 0.0018712574850299401],
#  ['lotus siam', 0.0018712472862372487],
#  ['palak paneer', 0.0018653453803555815],
#  ['chick fil', 0.0018623937030009137],
#  ['pinot grigio', 0.0018330605564648118],
#  ['senior citizens', 0.0018033490768570202],
#  ['sky harbor', 0.0017765310892940626],
#  ['tl dr', 0.0017667844522968198],
#  ['bobby flay', 0.0017598343685300208],
#  ['ufc fights', 0.0017507002801120449],
#  ['pigs blanket', 0.0017316017316017316],
#  ['mass produced', 0.001715730540003612],
#  ['rocket science', 0.0017006802721088435],
#  ['kim chee', 0.0017004830917874397],
#  ['tommy bahama', 0.001674603589931446],
#  ['granny smith', 0.0016720171214553237],
#  ['horizon ridge', 0.0016698779704560052],
#  ['jose andres', 0.0016638120871054563],
#  ['da vang', 0.0016621983914209115],
#  ['ins dives', 0.0016603053435114503],
#  ['santa barbara', 0.0016597510373443983],
#  ['michael mina', 0.0016246538669827419],
#  ['dee lish', 0.0016117216117216117],
#  ['cave creek', 0.001605627341539873],
#  ['emeril lagasse', 0.0015936762924714733],
#  ['ri ra', 0.0015681210220459367],
#  ['lake mead', 0.0015673103834312903],
#  ['isolated incident', 0.0015613740091280327],
#  ['speaks volumes', 0.0015544041450777201],
#  ['cross contamination', 0.0015404364569961489],
#  ['claim jumper', 0.0015400796333859214],
#  ['pep pep', 0.0015384615384615385],
#  ['dick hideaway', 0.0015356265356265355],
#  ['del frisco', 0.0014700940860215054],
#  ['james bond', 0.0014690853346959632],
#  ['miller lite', 0.001449025357943764],
#  ['spam musubi', 0.0014459699178629459],
#  ['copious amounts', 0.0014238494787693872],
#  ['eiffel tower', 0.0014195395443158774],
#  ['moo shu', 0.0014192727450692507],
#  ['banh xeo', 0.001418757467144564],
#  ['faux pas', 0.0013934563290786467],
#  ['frank sinatra', 0.0013884068031933356],
#  ['saving grace', 0.0013830870221504545],
#  ['vic anthony', 0.0013660035857594125],
#  ['saag paneer', 0.0013460703430308294],
#  ['capital grille', 0.001335693595107821],
#  ['cabernet sauvignon', 0.001331680213068834],
#  ['graham cracker', 0.00131986801319868],
#  ['ruth chris', 0.0013187062116725725],
#  ['moo goo', 0.0013180295458289856],
#  ['aesthetically pleasing', 0.0013148163365929821],
#  ['mandarin oriental', 0.0012980348356325655],
#  ['false advertising', 0.0012947269303201507],
#  ['ooey gooey', 0.0012912287060529177],
#  ['pico gallo', 0.0012893420923619963],
#  ['charlie palmer', 0.0012784032331230155],
#  ['dimly lit', 0.0012764461293873059],
#  ['cowboy ciao', 0.0012653495528139648],
#  ['shark fin', 0.0012626262626262627],
#  ['di beppo', 0.0012567234705675363],
#  ['sam adams', 0.0012509239779382498],
#  ['arrogant butcher', 0.001243100790612103],
#  ['dos gringos', 0.0012421906397281795],
#  ['tikka masala', 0.0012390873156092022],
#  ['jimmy johns', 0.001231060606060606],
#  ['nickel dime', 0.0012276691220049108],
#  ['united states', 0.001219333756035702],
#  ['cheba hut', 0.001217391304347826],
#  ['butternut squash', 0.0012168660567675345],
#  ['raising cane', 0.0012084909625893234],
#  ['gin tonic', 0.0012065637065637065],
#  ['prickly pear', 0.0012058598269428194],
#  ['santa monica', 0.0012011356191308146],
#  ['sticker shock', 0.0012],
#  ['tater tots', 0.0011858724227983973],
#  ['circus circus', 0.0011842092169292162],
#  ['bangers mash', 0.0011731948441997247],
#  ['bahn mi', 0.0011579544380376217],
#  ['cotton candy', 0.0011545014347202295],
#  ['papa johns', 0.0011482420019005386],
#  ['hamachi kama', 0.0011443393347574],
#  ['quiche lorraine', 0.0011441647597254005],
#  ['pf chang', 0.0011430290269213415],
#  ['brussel sprout', 0.0011384615384615385],
#  ['thomas keller', 0.001138195004029009],
#  ['banh mi', 0.0011320992999927833],
#  ['cast iron', 0.001125500628526325],
#  ['mai tai', 0.0011234336742042344],
#  ['award winning', 0.0011230547088079577],
#  ['gallo blanco', 0.0011203652813596583],
#  ['los angeles', 0.0011195329754886542],
#  ['tourist trap', 0.0011179358022153118],
#  ['di mare', 0.0011174785100286533],
#  ['gordon ramsay', 0.0011045964821003343],
#  ['cordon bleu', 0.0010955693138678692],
#  ['shoe string', 0.0010924045752473974],
#  ['mason jar', 0.0010867963454170352],
#  ['frutti di', 0.001080370144205928],
#  ['mon ami', 0.0010785753625849092],
#  ['planet hollywood', 0.0010746268656716418],
#  ['arcadia farms', 0.0010705838416531807],
#  ['gordon biersch', 0.0010685366057266883],
#  ['cracker barrel', 0.0010571768910065515],
#  ['shu mai', 0.0010524964702862277],
#  ['au poivre', 0.0010381135992881506],
#  ['locally sourced', 0.0010290627230327475],
#  ['jersey shore', 0.0010245245565729654],
#  ['blank stare', 0.0010181916915557969],
#  ['ka gai', 0.0010112359550561798],
#  ['video poker', 0.0010109142959384505],
#  ['pane bianco', 0.0010046999523193243],
#  ['nom nom', 0.0010037484381507705],
#  ['hop knot', 0.0010005717552887365],
#  ['squid ink', 0.0009995002498750624],
#  ['casa grande', 0.0009909768945913524],
#  ['tgi fridays', 0.0009888529306005035],
#  ['culinary dropout', 0.0009863739484549158],
#  ['timely manner', 0.0009850107066381156],
#  ['shabu shabu', 0.0009844529740429076],
#  ['slot machines', 0.0009788076756732148],
#  ['comme ca', 0.0009775171065493646],
#  ['gordon ramsey', 0.0009743366681165724],
#  ['del mar', 0.0009707287933094385],
#  ['earth shattering', 0.0009615928502743368],
#  ['liquor license', 0.0009596220565438843],
#  ['web site', 0.0009587727708533077],
#  ['bananas foster', 0.0009569377990430622],
#  ['dan dan', 0.000953552327911444],
#  ['del rey', 0.0009520609318996416],
#  ['cell phones', 0.0009497964721845319],
#  ['bang buck', 0.0009493546741987368],
#  ['char siu', 0.0009459459459459459],
#  ['security guard', 0.0009457159069415548],
#  ['ox tail', 0.0009427695999657175],
#  ['sierra nevada', 0.0009409907722195241],
#  ['bowling alley', 0.0009404388714733542],
#  ['tom kha', 0.0009292693288020391],
#  ['molten lava', 0.0009290580780408785],
#  ['pine nuts', 0.0009228291836987489],
#  ['tivoli village', 0.0009220839096357768],
#  ['cirque du', 0.0009208561473369836],
#  ['au gratin', 0.0009062896501721951],
#  ['bait switch', 0.0009042175289026675],
#  ['st francis', 0.0008974559076010614],
#  ['grass fed', 0.000895373643314284],
#  ['kha gai', 0.0008937691521961185],
#  ['kim chi', 0.0008838951310861424],
#  ['au jus', 0.0008838282928480426],
#  ['triple decker', 0.0008802816901408451],
#  ['diamond rough', 0.0008792721156051686],
#  ['cole slaw', 0.0008618884216970342],
#  ['crème brûlée', 0.0008605620545919054],
#  ['citizen public', 0.000856898029134533],
#  ['papa murphy', 0.0008568001370880219],
#  ['shish kabob', 0.0008557980316645272],
#  ['el gordo', 0.0008535609495865564],
#  ['holy moly', 0.0008524001794526693],
#  ['john silvers', 0.0008464681844716871],
#  ['cornish pasty', 0.0008462840436990306],
#  ['chit chat', 0.0008447043534762833],
#  ['siu mai', 0.0008414074451810301],
#  ['panda express', 0.000841310369093911],
#  ['macadamia nut', 0.0008196941600150501],
#  ['pommes frites', 0.0008187464709203839],
#  ['palate cleanser', 0.0008143774639545429],
#  ['brussel sprouts', 0.0008137741990748672],
#  ['mish mash', 0.0008119393751933189],
#  ['queen creek', 0.0008074475159114658],
#  ['corkage fee', 0.0008045176761816354],
#  ['mandalay bay', 0.0008019484376856362],
#  ['matzo ball', 0.0007950931394820536],
#  ['ala carte', 0.0007950456105113398],
#  ['track betting', 0.0007936507936507937],
#  ['clam chowder', 0.0007922759806093811],
#  ['social media', 0.0007919615898628917],
#  ['air conditioning', 0.0007818769161128372],
#  ['wicked spoon', 0.0007804663991975928],
#  ['pomme frites', 0.0007783145464304884],
#  ['golden corral', 0.0007778148165785673],
#  ['sporting events', 0.0007775854716933804],
#  ['rat pack', 0.0007775545908118965],
#  ['beard award', 0.0007768498737618955],
#  ['knock socks', 0.0007764810800006151],
#  ['miracle mile', 0.0007708049113233288],
#  ['samurai sam', 0.0007707026682257893],
#  ['tator tots', 0.0007680670313045502],
#  ['brussels sprouts', 0.0007679901697258275],
#  ['al dente', 0.0007618706771972919],
#  ['brightly colored', 0.0007605939876856212],
#  ['born raised', 0.0007571971589962594],
#  ['queso fundido', 0.000753632332579701],
#  ['bloody mary', 0.0007513878941681535],
#  ['bloody marys', 0.0007503255444701008],
#  ['forum shops', 0.0007478071061886091],
#  ['john dory', 0.0007420819852177269],
#  ['screaming orgasm', 0.0007388821329064237],
#  ['paled comparison', 0.0007382927858247785],
#  ['imperial palace', 0.000733264320220842],
#  ['holy grail', 0.0007150067294751009],
#  ['dress code', 0.000706766357921363],
#  ['donut holes', 0.000704694045335317],
#  ['ellis island', 0.0007022471910112359],
#  ['chase field', 0.0007005649717514124],
#  ['jack daniels', 0.0006974358974358975],
#  ['st louis', 0.0006911907475412604],
#  ['michael jackson', 0.0006898250800689825],
#  ['yukon gold', 0.0006807238917482982],
#  ['pickle spear', 0.0006753438113948919],
#  ['hockey puck', 0.000672109927312556],
#  ['aptly named', 0.0006712310377231843],
#  ['candied pecans', 0.0006588523711024285],
#  ['andy sage', 0.000658681977363296],
#  ['march madness', 0.0006586613973754877],
#  ['mile radius', 0.0006586065766571011],
#  ['san francisco', 0.0006556120390543049],
#  ['tony roma', 0.0006555169725745872],
#  ['di amore', 0.0006487538519759961],
#  ['los reyes', 0.0006444173110839778],
#  ['le cirque', 0.0006426533747139408],
#  ['le reve', 0.0006423683843038682],
#  ['candied walnuts', 0.0006379585326953748],
#  ['pale ale', 0.0006279880074548254],
#  ['violently ill', 0.0006254442075337598],
#  ['foie gras', 0.000624392736849372],
#  ['peach cobbler', 0.0006232193732193732],
#  ['generously portioned', 0.0006231306081754736],
#  ['mahi mahi', 0.0006229338769847169],
#  ['pizzeria bianco', 0.000617676337599098],
#  ['san diego', 0.0006153815613818294],
#  ['ah mazing', 0.0006151742993848256],
#  ['http www', 0.0006089550702656959],
#  ['texas roadhouse', 0.0006066979453162918],
#  ['general tso', 0.0006065200909780137],
#  ['tonkotsu shoyu', 0.0006046511627906977],
#  ['southern highlands', 0.0006041644190311792],
#  ['kalua pig', 0.0006009841114825527],
#  ['fettuccine alfredo', 0.000594138785093559],
#  ['chow mein', 0.0005932844365185652],
#  ['brightly lit', 0.0005925711808064749],
#  ['chow mien', 0.0005924170616113745],
#  ['texas brazil', 0.0005923860963498562],
#  ['air conditioned', 0.0005923771827079715],
#  ['caribbean jerk', 0.0005919854280510018],
#  ['creme brulee', 0.0005886671400123311],
#  ['finger licking', 0.0005872074704247945],
#  ['shoe leather', 0.0005857495502280239],
#  ['nacho daddy', 0.0005857303424147921],
#  ['swiss chard', 0.0005825734549138804],
#  ['concrete floors', 0.0005794205794205794],
#  ['19th ave', 0.00057693161141437],
#  ['gift certificate', 0.0005736323567539539],
#  ['marble rye', 0.0005690871841566128],
#  ['ma po', 0.0005663680362475544],
#  ['foo foo', 0.0005636702284089795],
#  ['4th july', 0.0005623461505814447],
#  ['pinnacle peak', 0.0005608239012949934],
#  ['wild thaiger', 0.0005588796107567888],
#  ['arm leg', 0.0005580050141859021],
#  ['rollin smoke', 0.0005567381693139021],
#  ['collard greens', 0.0005563898668110983],
#  ['health conscious', 0.0005544832426741534],
#  ['el encanto', 0.0005542283803153369],
#  ['kung pow', 0.0005495471731293414],
#  ['fridays saturdays', 0.0005490060101710588],
#  ['al pastor', 0.0005488224672979749],
#  ['newport beach', 0.0005478360476119328],
#  ['mekong plaza', 0.000545404963185165],
#  ['hearts palm', 0.000542933511526896],
#  ['lo behold', 0.0005428528000347426],
#  ['chilean seabass', 0.000533639022847656],
#  ['golden nugget', 0.0005304235811169206],
#  ['barrio queen', 0.0005247277974550702],
#  ['oyster shooters', 0.0005228758169934641],
#  ['el cortez', 0.0005220991988477811],
#  ['multi grain', 0.0005218830981860063],
#  ['grand marnier', 0.0005126452494873548],
#  ['fois gras', 0.0005122738750672683],
#  ['sen japan', 0.000511959370904325],
#  ['condensed milk', 0.0005102669223866416],
#  ['facebook page', 0.000509779442363712],
#  ['bocce ball', 0.000508397981471718],
#  ['lo mein', 0.0005067367953003667],
#  ['color scheme', 0.0005059898255018872],
#  ['roaring fork', 0.0005054142501547831],
#  ['text message', 0.0005037407414317432],
#  ['coal fired', 0.0004985846628924344],
#  ['kung fu', 0.0004982561036372695],
#  ['fond memories', 0.00049813200498132],
#  ['apologized profusely', 0.0004935292827374424],
#  ['rising sun', 0.0004905254670071227],
#  ['sense humor', 0.0004900688979215314],
#  ['expense account', 0.00048484848484848484],
#  ['cookie cutter', 0.00048449612403100775],
#  ['puff pastry', 0.00048423937871174054],
#  ['sam woo', 0.0004836239555065961],
#  ['chit chatting', 0.0004830357832908262],
#  ['micro brews', 0.0004806536890170632],
#  ['st germain', 0.00047938638542665386],
#  ['creme fraiche', 0.0004777702622905058],
#  ['en route', 0.0004771820232517786],
#  ['pollo fundido', 0.00047635178049709953],
#  ['artichoke hearts', 0.0004759830259612437],
#  ['oiled machine', 0.00047565960609438873],
#  ['angel hair', 0.0004737901256276498],
#  ['dim sum', 0.0004733950547928834],
#  ['horse radish', 0.0004716981132075472],
#  ['tom kah', 0.00047138875225446797],
#  ['rewards program', 0.000468937575030012],
#  ['tastefully decorated', 0.0004686859218466225],
#  ['kalamata olives', 0.0004682817182817183],
#  ['moral story', 0.00046801013104283667],
#  ['sticky toffee', 0.0004679949500079813],
#  ['oatmeal stout', 0.00046776050662061027],
#  ['owned operated', 0.00046558771178060516],
#  ['jersey mike', 0.0004647320045440463],
#  ['bottomless mimosas', 0.00046242405880758376],
#  ['lesson learned', 0.0004623794171485758],
#  ['com biz_photos', 0.00045399491965546657],
#  ['cutting corners', 0.00045109254614676746],
#  ['grand lux', 0.00044845157627112516],
#  ['se ew', 0.0004483831829930896],
#  ['jalapeño poppers', 0.0004436929644685877],
#  ['port subs', 0.0004436834474828776],
#  ['firehouse subs', 0.0004435550420861528],
#  ['holy smokes', 0.000442728625061982],
#  ['strawberry shortcake', 0.0004424452474006342],
#  ['visually appealing', 0.00044199646402828775],
#  ['sea bass', 0.00044195953867236807],
#  ['au vin', 0.00044141637078975147],
#  ['st patrick', 0.0004409740147995182],
#  ['heart attack', 0.0004392708104546453],
#  ['monterey jack', 0.0004392156862745098],
#  ['sam fox', 0.00043846285327843877],
#  ['al forno', 0.0004351610095735422],
#  ['del sol', 0.0004330943847072879],
#  ['growing pains', 0.00043161918855592554],
#  ['answering questions', 0.00043072505384063173],
#  ['ufc fight', 0.00043004587155963305],
#  ['hash browns', 0.00042952216865260344],
#  ['self proclaimed', 0.00042856671904704344],
#  ['pot stickers', 0.0004280764200676833],
#  ['breaking bank', 0.000425531914893617],
#  ['hip hop', 0.0004235112080407104],
#  ['wedding reception', 0.0004232804232804233],
#  ['thinly sliced', 0.0004205370276368783],
#  ['wood fired', 0.0004199823165340407],
#  ['jimmy john', 0.00041836933255497177],
#  ['carne asada', 0.00041734984279107946],
#  ['benefit doubt', 0.00041480899787212485],
#  ['dw bistro', 0.00041282642089093705],
#  ['dairy queen', 0.00041197473221642406],
#  ['knocked socks', 0.0004118069024150482],
#  ['bone marrow', 0.0004104738653074628],
#  ['em gee', 0.0004085574208884267],
#  ['creme brûlée', 0.00040584699568262767],
#  ['pollo loco', 0.00040548615656033917],
#  ['tom ka', 0.00040498442367601246],
#  ['grape leaves', 0.0004048031597345702],
#  ['wood paneling', 0.00040404040404040404],
#  ['chile relleno', 0.00040389406561083487],
#  ['mango lassi', 0.0004026722796742015],
#  ['shuffle board', 0.00040257648953301127],
#  ['travel channel', 0.00040025106657812627],
#  ['creme brule', 0.00039973351099267156],
#  ['thousand island', 0.0003996101364522417],
#  ['royal mile', 0.00039903153966858813],
#  ['god forbid', 0.00039464411557434814],
#  ['trader joe', 0.0003945018894564179],
#  ['dj spinning', 0.0003944773175542406],
#  ['snap peas', 0.0003938709832364667],
#  ['sesame seed', 0.00039168209656744054],
#  ['sea urchin', 0.0003910511042048285],
#  ['pita jungle', 0.00038627380524613726],
#  ['ha ha', 0.0003860858750653442],
#  ['paper towels', 0.000385866030782571],
#  ['sesame seeds', 0.0003852080123266564],
#  ['liberty market', 0.0003851296360888269],
#  ['cigarette smoke', 0.0003822773704330388],
#  ['maple syrup', 0.00038209510228922233],
#  ['ramsay burgr', 0.00038002584175723947],
#  ['san marzano', 0.0003798670465337132],
#  ['papa john', 0.0003783325298852188],
#  ['rose crown', 0.0003777971519907004],
#  ['famous daves', 0.000377664633805181],
#  ['loose leaf', 0.00037726521744786587],
#  ['stone crabs', 0.00037473183253234406],
#  ['guilty pleasure', 0.00037351576629708264],
#  ['non existent', 0.0003732200275608636],
#  ['365 challenge', 0.00037211610022326965],
#  ['squeezed oj', 0.00037055782509670654],
#  ['chilean sea', 0.00037054350180711217],
#  ['christmas eve', 0.0003687995574405311],
#  ['al fresco', 0.00036841852344263084],
#  ['broccoli rabe', 0.0003677436301549777],
#  ['wild boar', 0.0003671071953010279],
#  ['le village', 0.0003664964848206717],
#  ['east coast', 0.0003662435618671163],
#  ['powdered sugar', 0.00036567046173308033],
#  ['hangover cure', 0.00036369826972482746],
#  ['po boy', 0.00036301287723358255],
#  ['cheesecake factory', 0.00036293640252117287],
#  ['weather permits', 0.0003613624937154349],
#  ['fireside lounge', 0.0003599193780593147],
#  ['exceeded expectations', 0.0003575199155389193],
#  ['zinc bistro', 0.00035714285714285714],
#  ['bomb diggity', 0.00035713462823437246],
#  ['sun prairie', 0.0003547028977684561],
#  ['jumbo lump', 0.000354280147026261],
#  ['mama mia', 0.00035422343324250684],
#  ['applewood smoked', 0.00035402705778227335],
#  ['stir fry', 0.00035400283675851796],
#  ['health department', 0.0003534014893348479],
#  ['gift certificates', 0.0003518648838845883],
#  ['tempe marketplace', 0.00035133376707872476],
#  ['military discount', 0.0003458815958815959],
#  ['cinco mayo', 0.00034444863614742404],
#  ['caesars palace', 0.0003438162778366914],
#  ['char broiled', 0.00034375],
#  ['jalapeno poppers', 0.00033917927659843887],
#  ['childhood memories', 0.00033751559175287986],
#  ['queso fresco', 0.0003370862266567788],
#  ['fellow yelpers', 0.00033653100338782886],
#  ['lasting impression', 0.0003358305347455438],
#  ['stomach ache', 0.0003342896042011086],
#  ['sierra gold', 0.00033322966188296976],
#  ['yorkshire pudding', 0.0003331314354936402],
#  ['eyed peas', 0.0003324026060364313],
#  ['partner crime', 0.0003302873499944952],
#  ['blood pressure', 0.00032985714648194666],
#  ['holy cow', 0.00032921173155688103],
#  ['cell phone', 0.00032907057627481405],
#  ['los dos', 0.00032890438794497837],
#  ['todd english', 0.00032783953744821626],
#  ['com user_local_photos', 0.00032591712119324007],
#  ['pepsi products', 0.0003255956485099211],
#  ['san fran', 0.00032517152798101],
#  ['fellow yelper', 0.00032384430502231795],
#  ['caught guard', 0.0003228836444757544],
#  ['famous dave', 0.00032246281689819306],
#  ['filet mignon', 0.00032171903163794746],
#  ['boca park', 0.000320500293140512],
#  ['steer clear', 0.0003204810267601657],
#  ['exposed brick', 0.0003182374541003672],
#  ['sense urgency', 0.00031748271482997034],
#  ['bento boxes', 0.00031733826428174754],
#  ['san tan', 0.00031684345409835606],
#  ['mariachi band', 0.00031624014790308455],
#  ['china poblano', 0.000316105579263474],
#  ['philly cheesesteak', 0.00031507013026520214],
#  ['locally owned', 0.00031356612482440297],
#  ['lack luster', 0.0003128283221777573],
#  ['clay pot', 0.000312263955877947],
#  ['tokyo lobby', 0.0003107453602503107],
#  ['rose rabbit', 0.00030968468468468467],
#  ['cure hangover', 0.0003095304423190021],
#  ['mardi gras', 0.0003070820804810953],
#  ['desert ridge', 0.0003049452868255468],
#  ['cab ride', 0.0003010083780665229],
#  ['yogurt parfait', 0.00030095759233926127],
#  ['toffee pudding', 0.00030063619925106217],
#  ['ajo al', 0.00030046831613411246],
#  ['veal cheeks', 0.00029978197674418607],
#  ['treasure island', 0.0002994743918836328],
#  ['movie theater', 0.0002990990990990991],
#  ['miyagi san', 0.00029903028749626214],
#  ['vegetarians vegans', 0.0002976311268043887],
#  ['fuego bistro', 0.00029761904761904765],
#  ['silky smooth', 0.00029717130068163664],
#  ['july 4th', 0.00029708853238265005],
#  ['cherry blossom', 0.0002966151384089012],
#  ['san antonio', 0.00029441205911794147],
#  ['rio carnival', 0.00029262398761539766],
#  ['falling apart', 0.00029039195064906525],
#  ['alma school', 0.0002891844997108155],
#  ['saturdays sundays', 0.0002874389192296637],
#  ['farmers market', 0.00028735632183908046],
#  ['lo lo', 0.0002863232908090224],
#  ['juke box', 0.00028504793988079816],
#  ['running errands', 0.00028396639319468365],
#  ['striped bass', 0.00028298703701688127],
#  ['farmer market', 0.0002804141501294219],
#  ['carving station', 0.0002803502164414335],
#  ['chile rellenos', 0.000279401873027371],
#  ['cloth napkins', 0.0002786888760263254],
#  ['malt vinegar', 0.0002783324257275973],
#  ['alaskan king', 0.00027822475397187347],
#  ['macadamia nuts', 0.00027693159789531985],
#  ['sake bombers', 0.00027607883112470267],
#  ['encore beach', 0.0002760181619950593],
#  ['stetson chopped', 0.00027499841347069153],
#  ['taken aback', 0.0002749890245608618],
#  ['locally grown', 0.00027370688372812575],
#  ['comfort zone', 0.0002734999579230834],
#  ['earl grey', 0.00027316352897748246],
#  ['sin city', 0.0002731325662126205],
#  ['hole wall', 0.0002729842861017282],
#  ['answered questions', 0.0002696408873636475],
#  ['fountain hills', 0.0002694614445583078],
#  ['7th ave', 0.0002693723623956182],
#  ['mon fri', 0.0002692240526223878],
#  ['micro brew', 0.0002692096625560422],
#  ['rental car', 0.0002691808154832805],
#  ['carnegie deli', 0.0002690100430416069],
#  ['god bless', 0.000268733850129199],
#  ['spur moment', 0.00026860059092130003],
#  ['alcoholic beverages', 0.00026856763925729444],
#  ['vast array', 0.0002682936523709209],
#  ['agedashi tofu', 0.0002677017802168384],
#  ['chalk board', 0.0002665333999666833],
#  ['salted caramel', 0.0002664539190541042],
#  ['epic fail', 0.0002659967489286242],
#  ['fancy schmancy', 0.00026584707957256977],
#  ['pomegranate seeds', 0.0002655055225148683],
#  ['elementary school', 0.00026508579140158085],
#  ['bank account', 0.00026506196718962676],
#  ['non descript', 0.00026428225344668103],
#  ['calorie count', 0.00026255141631902914],
#  ['heat lamp', 0.00026228072711652285],
#  ['heat lamps', 0.0002616586781479323],
#  ['mmm mmm', 0.00026144851492735787],
#  ['asu campus', 0.00026010404161664664],
#  ['runny yolk', 0.00025974565705261406],
#  ['la carte', 0.00025887130867827265],
#  ['bellagio fountains', 0.00025847665847665845],
#  ['grand canyon', 0.0002583212417007431],
#  ['brick oven', 0.0002558983666061706],
#  ['yellowtail collar', 0.00025545293770878365],
#  ['carne adovada', 0.00025535787245106414],
#  ['fall asleep', 0.0002548108284409654],
#  ['arcade games', 0.00025267249757045674],
#  ['health code', 0.0002514493259761123],
#  ['freezer burn', 0.00025035205758097326],
#  ['la bocca', 0.00025020605204285884],
#  ['golden gate', 0.00024948277960326154],
#  ['creme anglaise', 0.0002488369576977172],
#  ['saddle ranch', 0.0002485763355328573],
#  ['bento box', 0.0002467947531435482],
#  ['sporting event', 0.0002467407786241734],
#  ['grocery store', 0.00024516579130961315],
#  ['college students', 0.00024385918240666843],
#  ['shepherd pie', 0.00024363446396903968],
#  ['pleasantly surprised', 0.00024230008738539924],
#  ['english muffin', 0.00024173509075194467],
#  ['peking duck', 0.00024120141275113183],
#  ['blah blah', 0.000240625],
#  ['hidden gem', 0.0002389806138132778],
#  ['sonny boy', 0.00023876739841851712],
#  ['dijon mustard', 0.00023784487506884984],
#  ['diver scallops', 0.0002374297154081093],
#  ['foo young', 0.00023686579184234213],
#  ['diet coke', 0.00023628260756511338],
#  ['doggie bag', 0.00023562306592733384],
#  ['hits misses', 0.00023551809073334447],
#  ['key lime', 0.0002353288421422104],
#  ['pad kee', 0.0002348641967445434],
#  ['usual suspects', 0.00023470046353341547],
#  ['walking distance', 0.00023373148282476586],
#  ['eye contact', 0.00023309304182991749],
#  ['lack thereof', 0.0002323690019751365],
#  ['olive tapenade', 0.00023188253618242592],
#  ['west mississippi', 0.00023117985792946912],
#  ['carving stations', 0.00023093662566061197],
#  ['pad ew', 0.0002302013529984724],
#  ['slot machine', 0.00022996435552489363],
#  ['chai latte', 0.00022958817620892524],
#  ['shishito peppers', 0.00022939068100358422],
#  ['balsamic vinegar', 0.00022757875173054677],
#  ['personal preference', 0.00022692298157728634],
#  ['dill pickle', 0.00022530235576143185],
#  ['credit cards', 0.00022499747193851754],
#  ['wax paper', 0.00022400462461160488],
#  ['balsamic vinaigrette', 0.00022390298731365675],
#  ['belgian waffle', 0.00022363909035896267],
#  ['england clam', 0.0002230291540922365],
#  ['gastro pub', 0.00022177866489243733],
#  ['oysters rockefeller', 0.00022126727922766075],
#  ['dried cranberries', 0.0002211183852040212],
#  ['nut muffin', 0.0002208597046413502],
#  ['weather cools', 0.0002199597787833082],
#  ['sake bombs', 0.00021964282697213916],
#  ['blueberry hill', 0.00021961447300813817],
#  ['alla vodka', 0.00021939981960459278],
#  ['separate checks', 0.00021926805264472967],
#  ['timely fashion', 0.0002184557438794727],
#  ['18 gratuity', 0.0002181500872600349],
#  ['smiles faces', 0.00021814459630664418],
#  ['rough edges', 0.00021807278179092273],
#  ['iron skillet', 0.00021651270207852195],
#  ['hidden gems', 0.0002160493827160494],
#  ['crème brulee', 0.00021436227224008573],
#  ['com biz', 0.00021369420148189525],
#  ['poker machines', 0.00021334510409769735],
#  ['mgm grand', 0.00021292168474283053],
#  ['blue ribbon', 0.00021210407239819005],
#  ['final verdict', 0.00021208407955509474],
#  ['middle eastern', 0.0002115564269166803],
#  ['fortune cookie', 0.00021148640334686845],
#  ['kansas city', 0.00021133271694624223],
#  ['living social', 0.00021021075913502842],
#  ['slider truck', 0.0002090219861269122],
#  ['biscuits gravy', 0.00020851685149207805],
#  ['reasonably priced', 0.00020841750841750842],
#  ['ruby tuesday', 0.00020768719539211342],
#  ['lychee sorbet', 0.0002063983488132095],
#  ['corn cob', 0.00020609273538961038],
#  ['jewish deli', 0.00020549378287900525],
#  ['tuck shop', 0.0002051890018694998],
#  ['flour tortillas', 0.0002051609980949336],
#  ['bun rieu', 0.00020432661609582917],
#  ['frog legs', 0.00020431300752753217],
#  ['yellow tail', 0.00020349701798600566],
#  ['olive garden', 0.00020165866787729425],
#  ['college student', 0.00020120724346076458],
#  ['onion rings', 0.00020043878104954115],
#  ['po boys', 0.00020028139536048148],
#  ['pre packaged', 0.00020009518041014105],
#  ['father law', 0.00019961433004911266],
#  ['indoor outdoor', 0.0001990300923790892],
#  ['cab driver', 0.0001985856824566502],
#  ['belly dancer', 0.00019852348160555867],
#  ['mouth watering', 0.00019804616098880227],
#  ['doggy bag', 0.0001977645283682229],
#  ['sub par', 0.00019737742226581803],
#  ['misses mark', 0.00019670560867557257],
#  ['learned lesson', 0.0001963529031726829],
#  ['stuffing cranberry', 0.00019615800865800865],
#  ['sun dried', 0.00019516869700627741],
#  ['brother law', 0.00019501064357157436],
#  ['3pm 6pm', 0.00019390754988428098],
#  ['elite event', 0.00019340489314379654],
#  ['gas station', 0.00019269030489178],
#  ['debit card', 0.000192440754194776],
#  ['creamed spinach', 0.00019215529615393228],
#  ['balsamic reduction', 0.00019212065176931113],
#  ['weekly basis', 0.00019017115403863476],
#  ['finely chopped', 0.00018825174637111144],
#  ['eggplant parmigiana', 0.00018797795531251335],
#  ['fork knife', 0.0001879138803214079],
#  ['baked goods', 0.00018786508938268705],
#  ['answer questions', 0.00018781496641552986],
#  ['grand canal', 0.00018780802134535306],
#  ['blue nile', 0.0001876172607879925],
#  ['san marco', 0.00018674136321195143],
#  ['flat screen', 0.00018661237942901458],
#  ['24 hrs', 0.00018652705590753316],
#  ['mother law', 0.0001859879537033063],
#  ['gluten intolerant', 0.00018550858137110032],
#  ['shepherds pie', 0.00018542639024566736],
#  ['greeted warmly', 0.0001852576647097195],
#  ['neon lights', 0.00018477043673012318],
#  ['linguine clams', 0.00018387576684552763],
#  ['kicks ass', 0.00018268176835951772],
#  ['herbs rye', 0.00018263728235723854],
#  ['taxi ride', 0.00018253637950043443],
#  ['pleasantly suprised', 0.00018232051947323394],
#  ['fell asleep', 0.00018186226964112513],
#  ['total rewards', 0.0001815339124973833],
#  ['fortune cookies', 0.00018118258941893678],
#  ['olive oil', 0.00018100433041283483],
#  ['melts mouth', 0.00018099901673507125],
#  ['san jose', 0.00018095884376822982],
#  ['poorly executed', 0.00018091361374943465],
#  ['shepard pie', 0.00018090379536162668],
#  ['boars head', 0.00018024165255846588],
#  ['paradise bakery', 0.00018023496084896128],
#  ['sharp cheddar', 0.0001798518021150572],
#  ['banana nut', 0.00017952298884728907],
#  ['smoked gouda', 0.00017946072053479296],
#  ['flat screens', 0.0001787101787101787],
#  ['bun bo', 0.00017806777386664632],
#  ['asu students', 0.0001780041625588783],
#  ['blue moon', 0.00017783291976840364],
#  ['west coast', 0.00017681721203216706],
#  ['sloppy joe', 0.00017652195018928827],
#  ['kumamoto oysters', 0.000175897782280761],
#  ['wedding anniversary', 0.00017571604287471446],
#  ['duck confit', 0.00017530239663419398],
#  ['sundried tomatoes', 0.00017523291374785653],
#  ['dogfish head', 0.0001749617004570341],
#  ['lightly breaded', 0.00017463259987641385],
#  ['redeeming factor', 0.00017412935323383086],
#  ['satisfy hunger', 0.00017399557102182854],
#  ['la condesa', 0.00017397997648634257],
#  ['los taquitos', 0.00017375786606555838],
#  ['golden tee', 0.00017294056609211967],
#  ['prime rib', 0.0001728435550121734],
#  ['picky eater', 0.0001727890356165995],
#  ['bike ride', 0.00017139048465420384],
#  ['bon appetite', 0.00017131970998999493],
#  ['baked ziti', 0.00017107267915853627],
#  ['screen tvs', 0.00017105338181307812],
#  ['pineapple upside', 0.00017083351902194097],
#  ['1000 island', 0.00017070142768466792],
#  ['fully stocked', 0.00017037710131758292],
#  ['fat tire', 0.0001700596844084703],
#  ['coconut bark', 0.00016935757028339166],
#  ['virgin olive', 0.00016934373896563404],
#  ['shopping center', 0.00016931586130465568],
#  ['holy crap', 0.0001691697992103751],
#  ['flat iron', 0.00016876887546633505],
#  ['ramen sora', 0.0001681298217611067],
#  ['add ons', 0.00016797711829500924],
#  ['foot traffic', 0.000167680370726056],
#  ['spring mtn', 0.00016668107120368426],
#  ['field greens', 0.00016654275092936802],
#  ['tri tip', 0.00016643213127248268],
#  ['irish pubs', 0.00016604609036932676],
#  ['fell apart', 0.00016604265676350464],
#  ['melting pot', 0.0001658374792703151],
#  ['passion fruit', 0.00016525346462436177],
#  ['cinnamon raisin', 0.00016490390083020586],
#  ['juices smoothies', 0.00016462410828608012],
#  ['bean curd', 0.00016458750257167972],
#  ['brazilian steakhouses', 0.0001644183115022353],
#  ['butterscotch pudding', 0.000164402526607251],
#  ['rewards card', 0.0001643950263032042],
#  ['final straw', 0.00016344676538851297],
#  ['chile verde', 0.00016271251331012287],
#  ['linguini clams', 0.00016245106161768768],
#  ['frequent visitor', 0.00016205704407951598],
#  ['denny ihop', 0.00016186711838885753],
#  ['credit card', 0.0001615184647144277],
#  ['dark stormy', 0.00016147149677057007],
#  ['movie theatre', 0.0001612662386143049],
#  ['fillet mignon', 0.00016122050548149719],
#  ['conveniently located', 0.0001595695751506994],
#  ['break bank', 0.0001594676083475539],
#  ['genghis grill', 0.00015942606616181745],
#  ['toilet paper', 0.00015894246282845609],
#  ['hold candle', 0.00015850235448042928],
#  ['cajun albacore', 0.00015781734759078348],
#  ['dime dozen', 0.00015779626248281148],
#  ['snow peas', 0.0001575386896487814],
#  ['bomb dot', 0.0001574826769055404],
#  ['velvet cupcake', 0.00015747067108750994],
#  ['blue fin', 0.00015734265734265734],
#  ['mind blowing', 0.0001558190299454563],
#  ['centrally located', 0.0001556925650127668],
#  ['players card', 0.00015553199010250973],
#  ['michelin rated', 0.00015515422329795818],
#  ['jason deli', 0.00015502273666804465],
#  ['spring mountain', 0.00015499575801083338],
#  ['convention center', 0.00015498646147674746],
#  ['cheek ravioli', 0.0001548425678237144],
#  ['word caution', 0.00015427115846876907],
#  ['plain jane', 0.0001541940789473684],
#  ['refried beans', 0.0001541216310922794],
#  ['comfy couches', 0.00015376592814451322],
#  ['luke warm', 0.00015361788861579042],
#  ['iceberg lettuce', 0.00015335521636137016],
#  ['low carb', 0.00015262769743803507],
#  ['dance floor', 0.00015252574846166093],
#  ['marzano tomatoes', 0.0001520610888896235],
#  ['originally planned', 0.00015194489465153972],
#  ['freshly squeezed', 0.00015189296608989533],
#  ['mignon merlot', 0.0001517933651609744],
#  ['cryin loud', 0.00015126304643775526],
#  ['el pollo', 0.00015115703842137086],
#  ['ahi poke', 0.0001507586931231422],
#  ['guy fieri', 0.00014963771920613252],
#  ['brewing company', 0.0001492344273875021],
#  ['sets apart', 0.0001487116424056968],
#  ['lamb chops', 0.00014832268235214348],
#  ['fashion square', 0.0001481967870936558],
#  ['lamb shank', 0.00014810865250747948],
#  ['32 oz', 0.00014739029309099013],
#  ['cash register', 0.00014729709824716454],
#  ['lightly battered', 0.00014709943922091334],
#  ['med rare', 0.0001470109851612742],
#  ['pub crawl', 0.0001462795449290544],
#  ['snow crabs', 0.00014618642069622463],
#  ['paper towel', 0.0001456752655538695],
#  ['noise level', 0.00014545162327225973],
#  ['bonus points', 0.00014479409537104416],
#  ['unlimited mimosas', 0.00014475377697219154],
#  ['teeny tiny', 0.0001444601222871733],
#  ['irish pub', 0.00014438936022155815],
#  ['light rail', 0.00014404811206943118],
#  ['golden steer', 0.00014372587016102254],
#  ['la diabla', 0.0001436876231073646],
#  ['greens proteins', 0.00014332422627312224],
#  ['camelback mountain', 0.00014277253690934472],
#  ['brownie sundae', 0.00014272461285948763],
#  ['21st birthday', 0.00014165492859394516],
#  ['mashed potatoes', 0.00014144736175122216],
#  ['dc ranch', 0.0001413583503135742],
#  ['venetian palazzo', 0.00014106944401435468],
#  ['safe bet', 0.00014096345913886988],
#  ['meyer lemon', 0.000140805406927626],
#  ['bus boy', 0.00014043684118599501],
#  ['bean sprouts', 0.0001401901295568405],
#  ['almond croissant', 0.0001401025681126555],
#  ['lettuce wraps', 0.00014000012375701547],
#  ['beautifully presented', 0.0001398014818957081],
#  ['degree weather', 0.00013978752296509305],
#  ['ihop denny', 0.00013928100884622624],
#  ['highest rated', 0.00013879250520471896],
#  ['kona grill', 0.00013871630756726765],
#  ['bus boys', 0.0001385556665621422],
#  ['baby backs', 0.00013834078431943615],
#  ['gonna lie', 0.00013831049952722955],
#  ['chip cookie', 0.00013793483958178158],
#  ['resort fee', 0.00013765888129215804],
#  ['dot com', 0.00013736628942634065],
#  ['wood burning', 0.0001372605090077209],
#  ['short leash', 0.00013689753675698863],
#  ['orange county', 0.0001363065192852427],
#  ['dripping grease', 0.0001359232898378806],
#  ['exact opposite', 0.00013539551111805447],
#  ['knife fork', 0.0001352979938314137],
#  ['orange blossom', 0.0001340875240841822],
#  ['greatly appreciated', 0.00013346003138979938],
#  ['credit debit', 0.00013339558460614953],
#  ['ride bike', 0.00013330371028660298],
#  ['picky eaters', 0.00013323705881341654],
#  ['year olds', 0.00013244651752037086],
#  ['andouille sausage', 0.0001323703829210437],
#  ['spaghetti meatballs', 0.00013218333829020853],
#  ['rainforest cafe', 0.00013204093268913362],
#  ['fig jam', 0.00013195355234957296],
#  ['south border', 0.00013193482419684676],
#  ['smoke ring', 0.0001316036849031773],
#  ['plan accordingly', 0.0001314102564102564],
#  ['gift card', 0.00013116264167567783],
#  ['carnival world', 0.00013097710970356197],
#  ['alcoholic beverage', 0.0001308251624986229],
#  ['30th birthday', 0.00013078345232645929],
#  ['football season', 0.00013057789340901923],
#  ['sunday funday', 0.00013022892384398574],
#  ['grocery stores', 0.0001301394932693481],
#  ['stamp card', 0.00013008130081300812],
#  ['7th st', 0.0001300660735653712],
#  ['boiled peanuts', 0.00012994546931198515],
#  ['tonkotsu ramen', 0.00012952380952380952],
#  ['deal breaker', 0.00012945029108822213],
#  ['piquillo peppers', 0.00012939521800281294],
#  ['dill pickles', 0.0001292156609381057],
#  ['cost effective', 0.00012905527741191027],
#  ['video games', 0.000128975752558519],
#  ['pinto beans', 0.0001289198417135754],
#  ['adult beverages', 0.00012875536480686696],
#  ['severely lacking', 0.00012873005722258672],
#  ['screen tv', 0.0001285355589191489],
#  ['scrambled eggs', 0.00012846005014203663],
#  ['blue adobe', 0.0001282051282051282],
#  ['wynn encore', 0.00012777066327493634],
#  ['lava cake', 0.00012741230165772506],
#  ['melt mouth', 0.00012724852113359344],
#  ['craft brews', 0.0001271766777538642],
#  ['readily available', 0.00012681816740702642],
#  ['bagel lox', 0.00012680452594615685],
#  ['willing overlook', 0.00012656566414160353],
#  ...]

# %%
Top100 = []
for i in range(100):
    Top100.append(Top[i][0])
Top100
# Out:
# ['knick knacks',
#  'rula bula',
#  'ropa vieja',
#  'itty bitty',
#  'dac biet',
#  'gulab jamun',
#  'patatas bravas',
#  'puerto rican',
#  'wal mart',
#  'bradley ogden',
#  'lomo saltado',
#  'vice versa',
#  'valle luna',
#  'kao tod',
#  'artery clogging',
#  'har gow',
#  'pina colada',
#  'bells whistles',
#  'harry potter',
#  'aguas frescas',
#  'ping pang',
#  'casey moore',
#  'pin kaow',
#  'cochinita pibil',
#  'scantily clad',
#  'demi glace',
#  'lactose intolerant',
#  'thit nuong',
#  'kilt lifter',
#  'moscow mule',
#  'woody allen',
#  'hustle bustle',
#  'dulce leche',
#  'cabo wabo',
#  'kee mao',
#  'tres leches',
#  'arnold palmer',
#  'coca cola',
#  'stainless steel',
#  'kool aid',
#  'osso bucco',
#  'rick moonen',
#  'van buren',
#  'huli huli',
#  'fleur lys',
#  'insult injury',
#  'quench thirst',
#  'bok choy',
#  'fogo chao',
#  'jean philippe',
#  'toby keith',
#  'tilted kilt',
#  'identity crisis',
#  'parmigiano reggiano',
#  'hush puppies',
#  'sierra bonita',
#  'nba finals',
#  'panna cotta',
#  'apache junction',
#  'petit fours',
#  'hong kong',
#  'peter piper',
#  'dean martin',
#  'lechon kawali',
#  'sauvignon blanc',
#  'osso buco',
#  'kare kare',
#  'pet peeve',
#  'croque madame',
#  'adam richman',
#  'alice wonderland',
#  'wi fi',
#  'santa fe',
#  'pang pong',
#  'monte carlo',
#  'conveyor belt',
#  'lau lau',
#  'daniel boulud',
#  'agua fresca',
#  'dietary restrictions',
#  'jean georges',
#  'caffe boa',
#  'pei wei',
#  'huevos rancheros',
#  'ho hum',
#  'johnny rockets',
#  'joel robuchon',
#  'tar tar',
#  'beaten path',
#  'du jour',
#  'wolfgang puck',
#  'bon appetit',
#  'flip flops',
#  'beverly hills',
#  'loco moco',
#  'cous cous',
#  'baba ganoush',
#  'smack dab',
#  'amuse bouche',
#  'bamboo shoots']

# %%
#Check point
assert len(restaurant_reviews_txt) == 143361

# %% [markdown]
# *Copyright &copy; 2019 The Data Incubator.  All rights reserved.*
